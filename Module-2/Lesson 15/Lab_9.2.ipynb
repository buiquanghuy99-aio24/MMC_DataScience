# %% [markdown]
# # Lab: Làm việc với dữ liệu trong Pandas

# %% [markdown]
# # 1. Đọc dữ liệu từ file

# %%
import pandas as pd

# %% [markdown]
# Đầu tiên, hãy đọc dữ liệu bằng Pandas từ file data Google_Playstore.csv

# %%
# Yêu cầu: Hãy đọc dữ liệu từ file Google_Playstore.csv
df_google_playstore = pd.read_csv('google-playstore-apps/Google-Playstore.csv')
df_google_playstore.head(2)
# Out:
#               App Name                      App Id   Category  Rating  \
# 0              Gakondo         com.ishakwe.gakondo  Adventure     0.0
# 1  Ampere Battery Info  com.webserveis.batteryinfo      Tools     4.4
#
#    Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0           0.0      10+              10.0                15  True    0.0
# 1          64.0   5,000+            5000.0              7662  True    0.0
#
#    ...                Developer Website         Developer Email      Released  \
# 0  ...      https://beniyizibyose.tk/#/  jean21101999@gmail.com  Feb 26, 2020
# 1  ...  https://webserveis.netlify.app/    webserveis@gmail.com  May 21, 2020
#
#    Last Updated Content Rating  \
# 0  Feb 26, 2020       Everyone
# 1  May 06, 2021       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# ...

# %% [markdown]
# Ngay sau khi đọc dữ liệu bằng Pandas, hãy nhanh chóng quan sát tổng quan về dữ liệu như tên cột, kiểu dữ liệu của từng cột và số lượng dữ liệu không khuyết ở từng cột

# %% [markdown]
# # 2. Chuyển đổi kiểu dữ liệu

# %%
df_google_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %% [markdown]
# Bây giờ, dựa vào thông tin được cung cấp từ câu lệnh trên, chúng ta cần kiểm tra xem các cột có đúng định dạng chưa và đưa những cột dữ liệu về đúng dạng, điều này giúp cho việc phân tích dữ liệu được hiệu quả.
# Có  nhiều cách khác nhau để xử lý về kiểu dữ liệu, tuy nhiên hãy xử lý một cách có trình tự, đừng chọn cột một cách ngẫu nhiên, điều đó sẽ làm rối quá trình xử lý dữ liệu, cách tốt nhất là hãy xử lý chúng theo một trình tự nhất định. Trình tự đó có thể là từng cột trong dữ liệu, hoặc từng kiểu dữ liệu trong Pandas.
# Trong bài asm này, chúng ta sẽ thực hiện bằng cách quan sát từng kiểu dữ liệu theo thứ tự kiểu dữ liệu có sẵn của output áp cuối trong câu lệnh trên: bool, float, int, object.

# %%
# Yêu cầu: Hãy in ra những cột dữ liệu có kiểu dữ liệu là bool.
df_google_playstore.select_dtypes(['bool'])
# Out:
#          Free  Ad Supported  In App Purchases  Editors Choice
# 0        True         False             False           False
# 1        True          True             False           False
# 2        True         False             False           False
# 3        True          True             False           False
# 4        True         False             False           False
# ...       ...           ...               ...             ...
# 2312939  True         False             False           False
# 2312940  True         False             False           False
# 2312941  True         False             False           False
# 2312942  True          True             False           False
# 2312943  True          True             False           False
#
# [2312944 rows x 4 columns]

# %% [markdown]
# Có vẻ như chúng ta không gặp khó khăn khi kiểm tra những cột dữ liệu có kiểu bool như trên. Tiếp theo hãy in ra những cột có kiểu dữ liệu là float.

# %%
# Yêu cầu: Hãy in ra những cột dữ liệu có kiểu dữ liệu là float.
df_google_playstore.select_dtypes(['float'])
# Out:
#          Rating  Rating Count  Minimum Installs  Price
# 0           0.0           0.0              10.0    0.0
# 1           4.4          64.0            5000.0    0.0
# 2           0.0           0.0              50.0    0.0
# 3           5.0           5.0              10.0    0.0
# 4           0.0           0.0             100.0    0.0
# ...         ...           ...               ...    ...
# 2312939     4.3       16775.0          100000.0    0.0
# 2312940     0.0           0.0             100.0    0.0
# 2312941     0.0           0.0             100.0    0.0
# 2312942     3.5           8.0            1000.0    0.0
# 2312943     5.0          12.0             100.0    0.0
#
# [2312944 rows x 4 columns]

# %%
# Yêu cầu: Hãy chuyển kiểu dữ liệu của Rating Count về dạng int
df_google_playstore['Rating Count'] = df_google_playstore['Rating Count'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Yêu cầu: Hãy chuyển kiểu dữ liệu của Rating Count về dạng int
# ----> 2 df_google_playstore['Rating Count'] = df_google_playstore['Rating Count'].astype('int')
#
# File c:\Users\Admin\anaconda3\envs\aio24_env\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %% [markdown]
# Lỗi thông báo: Cannot convert non-finite values (NA or inf) to integer. Tức là bạn không thể chuyển thành kiểu dữ liệu int do trong cột dữ liệu của bạn đang có giá trị null.
# Có nhiều cách khác nhau để xử lý về dữ liệu null:
# - Bỏ những dòng dữ liệu có giá trị null.
# - Thay thế giá trị null bằng giá trị khác.
#
# Việc thay thế giá trị null bằng giá trị khác cũng có nhiều cách khác nhau:
#
# - Thay thế bằng giá trị âm (áp dụng khi dữ liệu phân phối dương)
# - Thay thế bằng giá trị ngoài phân phối: 9999, 99999, ...
# - Thay thế bằng giá trị mean, median, mode (áp dụng khi giả định rằng dữ liệu bị khuyết có thể thuộc phân phối chung của dữ liệu)

# %%
# Yêu cầu: Hãy in ra giá trị lớn nhất và nhỏ nhất của cột Rating Count
print('Min rating count:', df_google_playstore['Rating Count'].min())
print('Max rating count:', df_google_playstore['Rating Count'].max())
# Out:
# Min rating count: 0.0
# Max rating count: 138557570.0

# %% [markdown]
# Từ kết quả trên cho thấy Rating Count thấp nhất là 0, cũng có nghĩa là có một số App nào đó chưa có người đánh giá. Điều này cho thấy tất cả giá trị của cột dữ liệu này mang phân phối dương, do đó để thay thế giá trị cho null, chúng ta chỉ cần gán 1 giá trị âm bất kì (chủ yếu là -1)

# %%
df_google_playstore[df_google_playstore['Rating Count'].isna()]
# Out:
#                                   App Name  \
# 115                               VM-Delay
# 210                               Promotor
# 284                             xrsta xatr
# 501                              GridChats
# 662                  Restaurant POS(Admin)
# ...                                    ...
# 2312553               Merlins Idle Apelsin
# 2312712                   Joule Mobile App
# 2312751                  Iris Profissional
# 2312764                   Wool Sort Puzzle
# 2312842  Living Goods (Innovation Network)
#
#                                                     App Id          Category  \
# 115                                       com.irv.vm_delay             Tools
# 210                              com.touchesbegan.promotor      Productivity
# 284                                         com.xrsta.xatr     Entertainment
# 501                              com.thegridnet.conference     Communication
# ...

# %%
# Yêu cầu: Hãy gán giá trị -1 cho giá trị bị khuyết
df_google_playstore_copy = df_google_playstore.copy()
df_google_playstore_copy['Rating Count'] = df_google_playstore_copy['Rating Count'].fillna(-1)

# %%
df_google_playstore_copy[df_google_playstore_copy['Rating Count'] == -1]
# Out:
#                                   App Name  \
# 115                               VM-Delay
# 210                               Promotor
# 284                             xrsta xatr
# 501                              GridChats
# 662                  Restaurant POS(Admin)
# ...                                    ...
# 2312553               Merlins Idle Apelsin
# 2312712                   Joule Mobile App
# 2312751                  Iris Profissional
# 2312764                   Wool Sort Puzzle
# 2312842  Living Goods (Innovation Network)
#
#                                                     App Id          Category  \
# 115                                       com.irv.vm_delay             Tools
# 210                              com.touchesbegan.promotor      Productivity
# 284                                         com.xrsta.xatr     Entertainment
# 501                              com.thegridnet.conference     Communication
# ...

# %%
# Yêu cầu: Hãy chuyển cột Rating Count về kiểu dữ liệu int
df_google_playstore_copy['Rating Count'] = df_google_playstore_copy['Rating Count'].astype('int')

print('Rating Count dtype:', df_google_playstore_copy['Rating Count'].dtypes)
# Out:
# Rating Count dtype: int32

# %% [markdown]
# Bây giờ, bạn cần chuyển kiểu dữ liệu của Mininum Installs về kiểu dữ liệu int nhưng bằng cách xóa giá trị Null

# %%
df_google_playstore[df_google_playstore['Minimum Installs'].isnull()]
# Out:
#                                  App Name  \
# 5622     Claire’s Café: Tasty Cuisine 🥞🧁🍔
# 43569                        Potato Smash
# 60888      SketchBook : Draw Art & Paints
# 64322        Shared grocery Shopping List
# 91391                          NBA NOW 21
# ...                                   ...
# 2161180                          DEEMO II
# 2170210   Lendor - Share & Rent Anything!
# 2205663               Local 24h Motorista
# 2212570                       Mitrasphere
# 2311821    DreamWorks Universe of Legends
#
#                                                   App Id         Category  \
# 5622                                   com.gamehouse.cc1           Casual
# 43569                      com.igg.android.projectpotato         Strategy
# 60888                       com.sketchbook.illustrations     Art & Design
# 64322                          com.tikamori.shoppinglist         Shopping
# 91391    com.com2us.nbanow2.android.google.global.normal           Sports
# ...

# %%
# Yêu cầu: Hãy xóa những dòng dữ liệu có giá trị Null hoặc NA ở cột Minimum Installs
df_google_playstore_copy.dropna(subset=['Minimum Installs'], inplace=True)

# %%
df_google_playstore_copy[df_google_playstore_copy['Minimum Installs'].isna()]
# Out:
# Empty DataFrame
# Columns: [App Name, App Id, Category, Rating, Rating Count, Installs, Minimum Installs, Maximum Installs, Free, Price, Currency, Size, Minimum Android, Developer Id, Developer Website, Developer Email, Released, Last Updated, Content Rating, Privacy Policy, Ad Supported, In App Purchases, Editors Choice, Scraped Time]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Yêu cầu: Hãy chuyển cột Minimum Installs về kiểu dữ liệu int
df_google_playstore_copy['Minimum Installs'] = df_google_playstore_copy['Minimum Installs'].astype('int')

print('Minimum Installs dtype:', df_google_playstore_copy['Minimum Installs'].dtypes)
# Out:
# Minimum Installs dtype: int32

# %% [markdown]
# Tiếp tục quan sát các cột với kiểu dữ liệu Object

# %%
# Yêu cầu: Quan sát các cột dữ liệu có kiểu dữ liệu là Object
df_google_playstore.select_dtypes(['object'])
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Installs  \
# 0                         com.ishakwe.gakondo      Adventure       10+
# 1                  com.webserveis.batteryinfo          Tools    5,000+
# ...

# %% [markdown]
# Ngay sau khi in ra các cột dữ liệu có kiểu object, chúng ta dễ dàng nhận ra 3 cột dữ liệu đang có sai định dạng về thời gian. Cụ thể cột Released, Last Updated, Scraped Time phải có kiểu dữ liệu là Datetime. Do đó chúng ta cần chuyển dữ liệu của 3 cột này về Datetime.
# Với phương thức astype, bạn vẫn có thể chuyển dữ liệu về dạng datetime bằng cú pháp .astype('datetime64[ns]'). Tuy nhiên, trong bài học này,chúng ta sẽ sử dụng một phương pháp như sau:
# <b>df['col_datetime'] = pd.to_datetime(df['col_datetime'])<b>

# %%
# Yêu cầu: Hãy chuyển đổi 3 cột Released, Last Updated,Scraped Time về dạng Datetime
df_google_playstore_copy['Released'] = pd.to_datetime(df_google_playstore_copy['Released'])
df_google_playstore_copy['Last Updated'] = pd.to_datetime(df_google_playstore_copy['Last Updated'])
df_google_playstore_copy['Scraped Time'] = pd.to_datetime(df_google_playstore_copy['Scraped Time'])

# %% [markdown]
# Quá trình chuyển đổi kiểu dữ liệu sang datetime có thể mất vài phút.
# Sau khi chuyển đổi thành công hãy in ra các cột có dữ liệu là datetime.

# %%
# Yêu cầu: Quan sát các cột dữ liệu có kiểu dữ liệu là Datetime
df_google_playstore_copy.select_dtypes(['datetime'])
# Out:
#           Released Last Updated        Scraped Time
# 0       2020-02-26   2020-02-26 2021-06-15 20:19:35
# 1       2020-05-21   2021-05-06 2021-06-15 20:19:35
# 2       2019-08-09   2019-08-19 2021-06-15 20:19:35
# 3       2018-09-10   2018-10-13 2021-06-15 20:19:35
# 4       2020-02-21   2018-11-12 2021-06-15 20:19:35
# ...            ...          ...                 ...
# 2312939        NaT   2021-06-01 2021-06-16 12:59:18
# 2312940 2018-01-17   2018-02-02 2021-06-16 12:59:19
# 2312941 2018-08-19   2018-08-19 2021-06-16 12:59:19
# 2312942 2016-08-01   2021-05-05 2021-06-16 12:59:19
# 2312943 2019-08-09   2019-08-19 2021-06-16 12:59:19
#
# [2312837 rows x 3 columns]

# %% [markdown]
# Hãy quay lại với kiểu dữ liệu object.

# %%
# Yêu cầu: Quan sát các cột dữ liệu có kiểu dữ liệu là Object
df_google_playstore_copy.select_dtypes(['object'])
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Installs  \
# 0                         com.ishakwe.gakondo      Adventure       10+
# 1                  com.webserveis.batteryinfo          Tools    5,000+
# ...

# %% [markdown]
# Tiếp theo chúng ta hãy xem xét trong dữ liệu này có cột nào là cột có kiểu dữ liệu hạng mục không. Về cơ bản dữ liệu hạng mục cũng có kiểu dữ liệu là object, tuy nhiên trong một cột số lượng duy nhất ít hơn rất nhiều so với tổng số mẫu trong dữ liệu, thường được sử dụng để phân thành các nhóm khác nhau cho từng mẫu dữ liệu. Ví dụ:
# - Giới tính: Nam - Nữ.
# - Thành phố: TP.HCM - Hà Nội - Huế

# %% [markdown]
# Bây giờ để xác định đâu là cột dữ liệu hạng mục, chúng ta cần tính tỉ lệ phần trăm phần tử duy nhất so với số lượng dữ liệu.

# %%
object_cols = df_google_playstore_copy.select_dtypes('object').columns.values
object_cols
# Out:
# array(['App Name', 'App Id', 'Category', 'Installs', 'Currency', 'Size',
#        'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Content Rating', 'Privacy Policy'],
#       dtype=object)

# %%
object_cols = object_cols[1:]
object_cols
# Out:
# array(['App Id', 'Category', 'Installs', 'Currency', 'Size',
#        'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Content Rating', 'Privacy Policy'],
#       dtype=object)

# %%
df_google_playstore_copy['App Id']
# Out:
# 0                           com.ishakwe.gakondo
# 1                    com.webserveis.batteryinfo
# 2                          com.doantiepvien.crm
# 3                       cst.stJoseph.ug17ucs548
# 4                          com.horodyski.grower
#                            ...
# 2312939                           com.rxsj.ssjj
# 2312940                com.threedream.oruonline
# 2312941    datastructure.appoworld.datastucture
# 2312942                       ishan.devi.suktam
# 2312943               com.yyazilim.biliyormusun
# Name: App Id, Length: 2312837, dtype: object

# %%
len(df_google_playstore_copy['App Id'])
# Out:
# 2312837

# %%
df_google_playstore_copy['App Id'].nunique()
# Out:
# 2312837

# %%
for col in object_cols:
    print(col, ':', df_google_playstore_copy[col].nunique() / len(df_google_playstore_copy[col]) * 100, '%')
# Out:
# App Id : 100.0 %
# Category : 0.002075373232095474 %
# Installs : 0.0009512127313770924 %
# Currency : 0.0006485541350298357 %
# Size : 0.07164361344962918 %
# Minimum Android : 0.006658489119639646 %
# Developer Id : 32.789037878588076 %
# Developer Website : 35.03934777937226 %
# Developer Email : 41.092389995490386 %
# Content Rating : 0.00025942165401193426 %
# Privacy Policy : 42.2730179428987 %

# %% [markdown]
# Chúng ta có thể thấy rằng với App Name, Với tỉ lệ gần 100% thì có thể dễ dàng khẳng định, đây không phải là dữ liệu hạng mục. Điều này là chính xác vì tên App không liên quan tới việc phân nhóm, mỗi App có một tên khác nhau.
#
# Bạn có thể nhận có khá nhiều cột dữ liệu có tỉ lệ giữa số lượng giá trị duy nhất và số lượng dữ liệu rất nhỏ, điều đó có nghĩa là có những giá trị được lặp lại nhiều lần và điều đó cho chúng thấy đây là dữ liệu hạng mục.

# %%
col_category = []
# Yêu cầu: Thêm tên cột vào list rỗng ở trên nếu tỉ lệ phần trăm phần tử duy nhất so với số lượng dữ liệu nhỏ hơn 5%
for col in object_cols:
    if ((df_google_playstore_copy[col].nunique() / len(df_google_playstore_copy[col])) <= 0.05):
        print(col)
        col_category.append(col)

print(col_category)
# Out:
# Category
# Installs
# Currency
# Size
# Minimum Android
# Content Rating
# ['Category', 'Installs', 'Currency', 'Size', 'Minimum Android', 'Content Rating']

# %%
# Yêu cầu: Chuyển kiểu dữ liệu của các cột được xác định là hạng mục về kiểu Category
for col in col_category:
    df_google_playstore_copy[col] = df_google_playstore_copy[col].astype('category')

# %%
df_google_playstore_copy.select_dtypes('category')
# Out:
#               Category  Installs Currency  Size Minimum Android Content Rating
# 0            Adventure       10+      USD   10M      7.1 and up       Everyone
# 1                Tools    5,000+      USD  2.9M      5.0 and up       Everyone
# 2         Productivity       50+      USD  3.7M    4.0.3 and up       Everyone
# 3        Communication       10+      USD  1.8M    4.0.3 and up       Everyone
# 4                Tools      100+      USD  6.2M      4.1 and up       Everyone
# ...                ...       ...      ...   ...             ...            ...
# 2312939   Role Playing  100,000+      USD   77M      4.1 and up           Teen
# 2312940      Education      100+      USD   44M      4.1 and up       Everyone
# 2312941      Education      100+      USD   29M      5.0 and up       Everyone
# 2312942  Music & Audio    1,000+      USD   10M      5.0 and up       Everyone
# 2312943         Trivia      100+      USD  5.2M      5.0 and up       Everyone
#
# ...

# %% [markdown]
# # 3. Apply

# %%
df_google_playstore['Size']
# Out:
# 0           10M
# 1          2.9M
# 2          3.7M
# 3          1.8M
# 4          6.2M
#            ...
# 2312939     77M
# 2312940     44M
# 2312941     29M
# 2312942     10M
# 2312943    5.2M
# Name: Size, Length: 2312944, dtype: object

# %%
df_google_playstore['Size'][row:= 0]
# Out:
# '10M'

# %%
text_list = []
for character in '2.9M':
    if not character.isdigit():
        text_list.append(character)
print(text_list)
# Out:
# ['.', 'M']

# %%
import re

match = re.findall(r'[A-Za-z]+$', '2.9M')
match
# Out:
# ['M']

# %%
import re

match = re.search(r'[A-Za-z]+$', '2.9M')
match.group()
# Out:
# 'M'

# %%
def get_last_letters(string):
    pattern = r'[A-Za-z\ ]+$'

    match = re.search(pattern, string)

    return match.group()

# %%
df_google_playstore['Size'].apply(lambda x: get_last_letters(str(x)))
# Out:
# 0          M
# 1          M
# 2          M
# 3          M
# 4          M
#           ..
# 2312939    M
# 2312940    M
# 2312941    M
# 2312942    M
# 2312943    M
# Name: Size, Length: 2312944, dtype: object

# %%
last_letters_series = df_google_playstore['Size'].apply(lambda x: get_last_letters(str(x)))

unique_letters = []
for value in last_letters_series:
    if value not in unique_letters:
        unique_letters.append(value)

print(unique_letters)
# Out:
# ['M', 'k', 'Varies with device', 'nan', 'G']

# %%
df_google_playstore[df_google_playstore['Size'].str.contains(r'device$', case=False, na=False)]['Size']
# Out:
# 115        Varies with device
# 137        Varies with device
# 140        Varies with device
# 154        Varies with device
# 180        Varies with device
#                   ...
# 2312738    Varies with device
# 2312745    Varies with device
# 2312751    Varies with device
# 2312755    Varies with device
# 2312842    Varies with device
# Name: Size, Length: 74777, dtype: object

# %%
import re

string = '2.9M n'

pattern = r'[A-Za-z\ ]+$'

re.findall(pattern, string)
# Out:
# ['M n']

# %% [markdown]
# Có khá nhiều loại kí tự đuôi để hỗ trợ cho giá trị cột Size, chúng ta cũng nên quan sát xem có những loại đuôi nào bằng phương thức Apply kết hợp với lambda và regex

# %%
import re

# Yêu cầu: Hãy xây dựng hàm để trả về kí tự trong chuỗi
def get_character(row):
    pattern = r'[A-Za-z\ ]+$'
    matches = re.search(pattern, str(row))
    if matches:
        return matches.group()
    return ''

# %% [markdown]
# Áp dụng hàm trên để trích xuất kí tự từ từng giá trị trong cột Size và kiểm tra xem có bao nhiêu loại khác nhau.

# %%
last_char = df_google_playstore['Size'].apply(lambda x: get_character(x))
last_char
# Out:
# 0          M
# 1          M
# 2          M
# 3          M
# 4          M
#           ..
# 2312939    M
# 2312940    M
# 2312941    M
# 2312942    M
# 2312943    M
# Name: Size, Length: 2312944, dtype: object

# %%
import numpy as np
np.array(last_char.unique())
# Out:
# array(['M', 'k', 'Varies with device', 'nan', 'G'], dtype=object)

# %%
df_google_playstore['Size']....
# Out:
# array(['M', 'k', 'Varies', nan, 'G'], dtype=object)
